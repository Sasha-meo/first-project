# %% [markdown]
# <div class="alert alert-success">
#   <b> ✔️Комментарий ревьюера ✔️</b>
#
# Привет, Александр! Меня зовут Михаил, я буду проверять твой проект. Предлагаю общаться на 'ты' :)
# Однако, если это неудобно - сообщи, и мы перейдем на 'Вы'. Моя главная цель —  поделиться с тобой своим опытом и помочь тебе стать крутым специалистом, а не только указать на совершенные тобой ошибки.
#
# Видно, что к проекту приложен большой труд. Все ключевые этапы в работе выполнены, статистическое исследование проведено качественно. Так что в целом справиться с задачей тебе удалось.
#
# Есть несколько аспектов, которые **требуют** твоего **внимания**. Комментарии по ним помечены красным цветом и символами ❌. После их доработки проект будет принят, осталось совсем немного :)
#
#
# Давай работать над проектом в диалоге: если **ты что-то меняешь** в проекте по моим рекомендациям — **пиши об этом**. Мне будет легче отследить изменения, если ты будешь использовать синюю форму, которую я прикреплю ниже. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
#
#
#
# Жду проект на повторное ревью. Успехов в изучении!
#
#
#
# </div>
# <div class="alert alert-block alert-danger"> <b>❌ Комментарий ревьюера ❌</b>
#     Так я выделяю моменты, которые требуют особого внимания. Нужно будет учесть их и внести корректировки в свою работу. </div>
# <div class="alert alert-block alert-warning"> <b>⚠️ Комментарий ревьюера ⚠️</b>
#     Желтым я отмечу рекомендации, которые, могут быть полезными при твоей работе. Они носят рекомендационный характер, но будет классно, если ты будешь учитывать их при работе.</div>
# <div class="alert alert-block alert-success"> <b>✔️ Комментарий ревьюера ✔️</b>
#     Так я выделяю удачные и элегантные решения, на которые можно опираться в будущих проектах.</div>
# <div class="alert alert-block alert-info">
#
# А в таком блоке ты можешь оставить комментарии для меня
#
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-warning">
#
# **⚠️ Комментарий ревьюера ⚠️**
#
#    Рекомендую добавить к работе небольшой план работы, написанный своими словами - навык составления ТЗ пригодится в будущем
#
# </div>

# %% [markdown]
# ТЗ:
# 1) Открываем таблицу и изучаем ее.
# 2) Выполняем предобработку данных для более качественного анализа.
# 3) Добавляем нужные нам столбцы и удаляем лишние данные.
# 4) Проводим анализ:
#  - проведение корреляционного анализа
#  - вычисление средней цены одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений
#  - расчет зависимости стоимости объектов от расстояния до центра города
#  - определяем факторы, которые больше всего влияют на общую стоимость объекта.
# 5) Общий вывод.

# %% [markdown]
# <div class="alert alert-warning">
#
# **⚠️ Комментарий ревьюера v2⚠️**
#
#    Пункт 4 можно расписать подробнее - проведение корреляционного анализа, вычисление средней цены одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений, расчет зависимости стоимости объектов от расстояния до центра города
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v3✔️**
#
#    👍
#
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep ='\t') 
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
data.hist(figsize=(15, 20))
# Out:
# array([[<AxesSubplot:title={'center':'total_images'}>,
#         <AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'rooms'}>],
#        [<AxesSubplot:title={'center':'ceiling_height'}>,
#         <AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'living_area'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'kitchen_area'}>,
#         <AxesSubplot:title={'center':'balcony'}>,
#         <AxesSubplot:title={'center':'airports_nearest'}>,
#         <AxesSubplot:title={'center':'cityCenters_nearest'}>],
#        [<AxesSubplot:title={'center':'parks_around3000'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>,
#         <AxesSubplot:title={'center':'ponds_around3000'}>,
#         <AxesSubplot:title={'center':'ponds_nearest'}>],
#        [<AxesSubplot:title={'center':'days_exposition'}>, <AxesSubplot:>,
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#    Хорошо. Гистограммы построены. Приступим к предобработке
#
# </div>

# %% [markdown]
# ### Предобработка данных

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Посмотрим процентное соотношение пропущенных значений.

# %%
data.isnull().sum()/len(data)* 100
# Out:
# total_images             0.000000
# last_price               0.000000
# total_area               0.000000
# first_day_exposition     0.000000
# rooms                    0.000000
# ceiling_height          38.799105
# floors_total             0.362885
# living_area              8.029875
# floor                    0.000000
# is_apartment            88.290645
# studio                   0.000000
# open_plan                0.000000
# kitchen_area             9.612220
# balcony                 48.605426
# locality_name            0.206760
# airports_nearest        23.384953
# cityCenters_nearest     23.287902
# parks_around3000        23.283683
# parks_nearest           65.909954
# ponds_around3000        23.283683
# ponds_nearest           61.559559
# days_exposition         13.422507
# dtype: float64

# %% [markdown]
# Заменим пропуски на нулевые значения в балконах, так как их скорее всего просто нет. Высоту потолков, площадь кухни и площадь квартиры заменим медианным значением.
# Удалим строки с пропусками в названии нас. пункта и высоты дома(потеряем меньше процента данных, это не так страшно).
# Расстояние до центра города и парка заменим на нуль для выполнения след. заданий.
# Пропуски в данных, которые вносятся без пользователя могли возникнуть из-за сбоя программы.
# А остальные просто потому что их не заполнил пользователь.

# %%
data.fillna({'balcony' : 0}, inplace = True)
#data.fillna({'cityCenters_nearest' : 0}, inplace = True)
#data.fillna({'parks_nearest' : 0}, inplace = True)
data.fillna({'is_apartment' : False}, inplace = True)
#data.fillna({'days_exposition' : 0}, inplace = True)
data['ceiling_height'].fillna(data['ceiling_height'].median(), inplace=True)
#data['kitchen_area'].fillna(data['kitchen_area'].median(), inplace=True)
#data['living_area'].fillna(data['living_area'].median(), inplace=True)
data = data.dropna(subset=['locality_name'])
data = data.dropna(subset=['floors_total'])
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area              1865
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area             2222
# balcony                     0
# locality_name               0
# airports_nearest         5524
# cityCenters_nearest      5501
# parks_around3000         5500
# parks_nearest           15535
# ponds_around3000         5500
# ponds_nearest           14529
# days_exposition          3171
# dtype: int64

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#    Так как число пропусков в столбцах locality_name и floors_total, мы действительно можем удалить их без потери качества данных👍
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера ❌**
#
#    Работая с картографическими данными (parks_nearest, parks_around_3000, ponds_around_3000 и т.п. ) нужно быть очень осторожным - размах выборки большой, поэтому заполнение пропусков может привести к тому, что данные окажутся неактуальными - стоит оставить пропуски без изменений. К тому же, согласно ТЗ, в дальнейшем анализе они не участвуют
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# закомментировал parks_nearest и cityCenters_nearest
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Исправлено👍
#
# </div>
#
#
# </div>

# %% [markdown]
#  <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера ❌**
#
#    По столбцу `days_exposition` - Мы можем заполнять только те данные, которые пропущенны совершенно случайно. Иначе заполнение может повлиять на характер связи между заполняемой величиной и остальными. Попробуй рассмотреть распределение пропусков в данном столбце относительно года выставления квартиры на продажу. Какой вывод ты сможешь сделать? Являются ли данные пропуски случайными?
#
# </div>

# %%
data['propuski'] = data['days_exposition'].isna()

data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format = '%Y-%m-%dT%H:%M:%S')
data['year_count'] = data['first_day_exposition'].dt.year

data.query('propuski == True').pivot_table(index='year_count', values='propuski', aggfunc='count')
# Out:
#             propuski
# year_count
# 2014              18
# 2015              70
# 2016              67
# 2017             271
# 2018             957
# 2019            1788

# %% [markdown]
# <div class="alert alert-block alert-info">
# Можем увидеть, что пропуски случайны только в 14,15 и 16 годах. Поэтому оставим пропущенные значения в исходном датафрейме.
# <div>

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Верно. Если рассматривать распределение пропусков относительно года выставления на продажу, можно заметить, что большая часть пропущенных значений - в 2019 году. Больше половины объектов, выставленных на продажу в 2019 году не имеет рассчитанного "времени продажи квартиры". Также высокая доля пропусков, хотя и меньшая - в 2018 году. Получается, чем свежей объявление - тем выше вероятность пропуска в этой колонке.
#
# Пропуск в этой колонке означает, что объект не продан и объявление не закрыто. Поэтому заполнять пропуски в этом столбце не надо - они не случайные и существенно влияют на статистику.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера ❌**
#
#    По столбцу living_area есть более точный способ, основанный на сильной корреляционной связи данного столбца со столбцом total_area: найти **соотношение медианной общей площади к медианной жилой**. А затем, заполнить пропуски в столбце `living_area` **отношением общей площади к найденному соотношению**.
#
#   Со столбцом `kitchen_area` можно поступить так же, как со столбцом `living_area`.
#
# </div>

# %%
median1 = data['total_area'].median()/data['living_area'].median()
median2 = data['total_area'].median()/data['kitchen_area'].median()
data['kitchen_area'].fillna(data['total_area']/median2, inplace=True)
data['living_area'].fillna(data['total_area']/median1, inplace=True)
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name               0
# airports_nearest         5524
# cityCenters_nearest      5501
# parks_around3000         5500
# parks_nearest           15535
# ponds_around3000         5500
# ponds_nearest           14529
# days_exposition          3171
# propuski                    0
# year_count                  0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Вроде бы все верно заполнил!
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Согласен👍
#
# </div>
#
#
# </div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  float64
#  2   total_area            23565 non-null  float64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  float64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               23565 non-null  float64
# ...

# %% [markdown]
# Заменим количество балконов, цену, квадратуру и кол-во этажей на целочисленный тип для удобства и логики переменных.
# Переменную со временем переведем в формат dt.
# Количество дней публикации объявления измеряется в штуках, поэтому переводим в целочисленный тип.

# %%
data['last_price'] = data['last_price'].astype(int)
data['total_area'] = data['total_area'].astype(int)
data['floors_total'] = data['floors_total'].astype(int)
data['balcony'] = data['balcony'].astype(int)
#data['days_exposition'] = data['days_exposition'].astype('int')
#data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format = '%Y-%m-%dT%H:%M:%S')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23565 non-null  int64
#  1   last_price            23565 non-null  int64
#  2   total_area            23565 non-null  int64
#  3   first_day_exposition  23565 non-null  datetime64[ns]
#  4   rooms                 23565 non-null  int64
#  5   ceiling_height        23565 non-null  float64
#  6   floors_total          23565 non-null  int64
#  7   living_area           23565 non-null  float64
#  8   floor                 23565 non-null  int64
#  9   is_apartment          23565 non-null  bool
#  10  studio                23565 non-null  bool
#  11  open_plan             23565 non-null  bool
#  12  kitchen_area          23565 non-null  float64
#  13  balcony               23565 non-null  int64
#  14  locality_name         23565 non-null  object
# ...

# %% [markdown]
# Изучим и устраним неявные дубликаты в столбце с районом.

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %%
data['locality_name'] = (
    data['locality_name']
    .str.replace('ё', 'е').replace('село', 'деревня').replace(['поселок городского типа', 'городской поселок', 'коттеджный поселок'], 'поселок', regex=True)
    .replace('поселок Рпоселок Рпоселок Рпоселок Рпоселок поселок поселок поселок Рябово', 'поселок Рябово')
    .replace('поселок городского типа Рпоселок Рпоселок Рпоселок Рпоселок поселок поселок поселок Рябово', 'поселок Рябово')
)

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'поселок Шушары', 'поселок Янино-1',
#        'поселок Парголово', 'поселок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок Красный Бор', 'Гатчина', 'деревня Федоровское', 'Выборг',
#        'Кронштадт', 'Кировск', 'деревня Новое Девяткино',
#        'поселок Металлострой', 'поселок Лебяжье', 'поселок Сиверский',
#        'поселок Молодцово', 'поселок Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'поселок Аннино',
#        'поселок Ефимовский', 'поселок Плодовое', 'деревня Заклинье',
#        'поселок Торковичи', 'поселок Первомайское', 'Красное Село',
#        'поселок Понтонный', 'Сясьстрой', 'деревня Старая',
#        'деревня Лесколово', 'поселок Новый Свет', 'Сланцы',
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#
#    Хорошая работа. Также рекомендую хорошую статью по предобработке, в ней есть интересные способы обработки неявных дубликатов: https://proglib.io/p/moem-dataset-rukovodstvo-po-ochistke-dannyh-v-python-2020-03-27 В пункте 8 есть интересная информация о работе с опечатками в названиях населенных пунктов
#
# </div>

# %%
data.hist(figsize=(15, 20))
# Out:
# array([[<AxesSubplot:title={'center':'total_images'}>,
#         <AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'first_day_exposition'}>],
#        [<AxesSubplot:title={'center':'rooms'}>,
#         <AxesSubplot:title={'center':'ceiling_height'}>,
#         <AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'living_area'}>],
#        [<AxesSubplot:title={'center':'floor'}>,
#         <AxesSubplot:title={'center':'kitchen_area'}>,
#         <AxesSubplot:title={'center':'balcony'}>,
#         <AxesSubplot:title={'center':'airports_nearest'}>],
#        [<AxesSubplot:title={'center':'cityCenters_nearest'}>,
#         <AxesSubplot:title={'center':'parks_around3000'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>,
#         <AxesSubplot:title={'center':'ponds_around3000'}>],
#        [<AxesSubplot:title={'center':'ponds_nearest'}>,
# ...

# %% [markdown]
# На этих гистограммах мы можем увидеть нормальные распределения и распределения Пуассона по каждому столбцу датафрейма.

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# Добавим в таблицу новые столбцы:
# - цена одного квадратного метра (делим стоимость объекта на его общую площадь, а затем округляем до двух знаков после запятой);
# - день недели публикации объявления (0 — понедельник, 1 — вторник и так далее);
# - месяц публикации объявления;
# - год публикации объявления;
# - тип этажа квартиры (значения — «‎первый», «последний», «другой»);
# - расстояние до центра города в километрах.

# %%
data['price_square_meter'] = data['last_price'] / data['total_area']
data['price_square_meter'] = round(data['price_square_meter'], 2)
data['weekday_day'] = data['first_day_exposition'].dt.weekday
data['month_count'] = data['first_day_exposition'].dt.month
data['year_count'] = data['first_day_exposition'].dt.year
def floor_category(row):
    floors_total = row['floors_total']
    floor = row['floor']
    if floor == 1:
        return 'первый'
    elif floor == floors_total:
        return 'последний'
    elif 1 < floor < floors_total:
        return 'другой'
data['floor_type'] = data.apply(floor_category, axis = 1)
data['cityCenters_nearest'] = data['cityCenters_nearest']/1000
data['distance_to_center'] = round(data['cityCenters_nearest'])

# %%
data
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20    13000000         108           2019-03-07      3
# 1                 7     3350000          40           2018-12-04      1
# 2                10     5196000          56           2015-08-20      2
# 3                 0    64900000         159           2015-07-24      3
# 4                 2    10000000         100           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9     9700000         133           2017-03-21      3
# 23695            14     3100000          59           2018-01-15      3
# 23696            18     2500000          56           2018-02-11      2
# 23697            13    11475000          76           2017-03-28      2
# 23698             4     1350000          32           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#    В данном блоке все верно👍
#
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# Изучим следующие параметры:
# - общая площадь;
# - жилая площадь;
# - площадь кухни;
# - цена объекта;
# - количество комнат;
# - высота потолков;
# - тип этажа квартиры («первый», «последний», «другой»);
# - общее количество этажей в доме;
# - расстояние до центра города в метрах;
# - расстояние до ближайшего парка
#
# Построим диаграмму размаха и гистограмму по этим столбцам.

# %%
numeric = ['total_area', 'living_area', 'kitchen_area', 'last_price', 'rooms', 'ceiling_height', 'floors_total', 'cityCenters_nearest', 'parks_nearest']
for column in numeric:
  if column in data.columns:
      plt.figure()
      plt.boxplot(data[column])
      plt.title(f'Boxplot for {column}')
      plt.show()

# %%
pd.plotting.scatter_matrix(data[numeric], figsize=(15, 15))
# Out:
# array([[<AxesSubplot:xlabel='total_area', ylabel='total_area'>,
#         <AxesSubplot:xlabel='living_area', ylabel='total_area'>,
#         <AxesSubplot:xlabel='kitchen_area', ylabel='total_area'>,
#         <AxesSubplot:xlabel='last_price', ylabel='total_area'>,
#         <AxesSubplot:xlabel='rooms', ylabel='total_area'>,
#         <AxesSubplot:xlabel='ceiling_height', ylabel='total_area'>,
#         <AxesSubplot:xlabel='floors_total', ylabel='total_area'>,
#         <AxesSubplot:xlabel='cityCenters_nearest', ylabel='total_area'>,
#         <AxesSubplot:xlabel='parks_nearest', ylabel='total_area'>],
#        [<AxesSubplot:xlabel='total_area', ylabel='living_area'>,
#         <AxesSubplot:xlabel='living_area', ylabel='living_area'>,
#         <AxesSubplot:xlabel='kitchen_area', ylabel='living_area'>,
#         <AxesSubplot:xlabel='last_price', ylabel='living_area'>,
#         <AxesSubplot:xlabel='rooms', ylabel='living_area'>,
# ...

# %%
data.hist(numeric, figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'living_area'}>,
#         <AxesSubplot:title={'center':'kitchen_area'}>],
#        [<AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'rooms'}>,
#         <AxesSubplot:title={'center':'ceiling_height'}>],
#        [<AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'cityCenters_nearest'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>]], dtype=object)

# %%
data['total_area'].describe()
# Out:
# count    23565.000000
# mean        60.095226
# std         35.668758
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.000000
# max        900.000000
# Name: total_area, dtype: float64

# %%
data['ceiling_height'].describe()
# Out:
# count    23565.000000
# mean         2.724530
# std          0.991026
# min          1.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера ❌**
#
#
#
#
#    Перед фильтрацией в данном столбце стоит рассмотреть все возможные значения столбца. Можно заметить значения 27. 24. и.т.п. Вероятно, продавец имел ввиду 2.7 2.4 Это можно исправить, и сохранить довольно большую долю данных
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Заменил вручную все значения, так как их не так уж и много
#
# </div>

# %%
print(data[data['ceiling_height'] > 10]['ceiling_height'].unique())
data['ceiling_height'] = data['ceiling_height'].replace(25.0, 2.50)
data['ceiling_height'] = data['ceiling_height'].replace(32.0, 3.20)
data['ceiling_height'] = data['ceiling_height'].replace(27.0, 2.70)
data['ceiling_height'] = data['ceiling_height'].replace(24.0, 2.40)
data['ceiling_height'] = data['ceiling_height'].replace(26.0, 2.60)
data['ceiling_height'] = data['ceiling_height'].replace(20.0, 2.00)
data['ceiling_height'] = data['ceiling_height'].replace(22.6, 2.26)
data['ceiling_height'] = data['ceiling_height'].replace(27.5, 2.75)
# Out:
# [ 25.   32.   27.   24.   26.   14.   20.   22.6  27.5  10.3 100. ]

# %% [markdown]
# <div class="alert alert-warning">
#
# **⚠️ Комментарий ревьюера v2⚠️**
#
#    Рекомендую ознакомиться с методом update для решения данной задачи:
#
# </div>

# %%
# Код ревьюера
data.update(data[(data['ceiling_height'] >= 20) & (data['ceiling_height'] <= 36)]['ceiling_height']/10)
data['ceiling_height'].unique()
# Out:
# array([  2.7 ,   2.65,   3.03,   2.5 ,   2.67,   2.56,   3.05,   2.75,
#          2.6 ,   2.9 ,   2.8 ,   2.55,   3.  ,   3.2 ,   2.61,   3.25,
#          3.45,   2.77,   2.85,   2.64,   2.57,   4.15,   3.5 ,   3.3 ,
#          2.71,   4.  ,   2.47,   2.73,   2.84,   3.1 ,   2.34,   3.4 ,
#          3.06,   2.72,   2.54,   2.51,   2.78,   2.76,   2.58,   3.7 ,
#          2.52,   5.2 ,   2.87,   2.66,   2.59,   2.  ,   2.45,   3.6 ,
#          2.92,   3.11,   3.13,   3.8 ,   3.15,   3.55,   3.16,   3.62,
#          3.12,   2.53,   2.74,   2.96,   2.46,   5.3 ,   5.  ,   2.79,
#          2.95,   4.06,   2.94,   3.82,   3.54,   3.53,   2.83,   4.7 ,
#          2.4 ,   3.38,   3.01,   5.6 ,   3.65,   3.9 ,   3.18,   3.35,
#          2.3 ,   3.57,   2.48,   2.62,   2.82,   3.98,   2.63,   3.83,
#          3.52,   3.95,   3.75,   2.88,   3.67,   3.87,   3.66,   3.85,
#          3.86,   4.19,   3.24,   4.8 ,   4.5 ,   4.2 ,   3.36,   3.08,
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Спасибо! Возьму на заметку.
#
# </div>

# %%
data.drop(data[(data['ceiling_height'] < 1.5) | (data['ceiling_height'] > 3)].index, inplace=True)

# %%
data['ceiling_height'].unique()
# Out:
# array([2.7 , 2.65, 2.5 , 2.67, 2.56, 2.75, 2.6 , 2.9 , 2.8 , 2.55, 3.  ,
#        2.61, 2.77, 2.85, 2.64, 2.57, 2.71, 2.47, 2.73, 2.84, 2.34, 2.72,
#        2.54, 2.51, 2.78, 2.76, 2.58, 2.52, 2.87, 2.66, 2.59, 2.  , 2.45,
#        2.92, 2.53, 2.74, 2.96, 2.46, 2.79, 2.95, 2.94, 2.83, 2.4 , 2.3 ,
#        2.48, 2.62, 2.82, 2.63, 2.88, 2.81, 2.97, 2.68, 2.93, 2.98, 2.86,
#        2.69, 2.2 , 2.99, 2.91, 1.75, 2.25, 2.26, 2.89, 2.49])

# %%
data['floors_total'].describe()
# Out:
# count    22058.000000
# mean        10.981186
# std          6.650005
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %%
data.drop(data[data['floors_total'] > 30].index, inplace=True)

# %%
data['floors_total'].unique()
# Out:
# array([16, 11,  5, 14, 12, 26, 24, 27,  9,  6, 17, 25,  3, 23, 19, 18,  4,
#        22,  2, 10,  7, 13, 15,  8, 20, 28, 21,  1, 29])

# %% [markdown]
# Опираясь на графики можем сделать выводы:
# - общая площадь
# Основная часть квартир имеет общую площадь до 100 кв. м. Судя по диаграмме размаха есть много выбросов и их не целесообразно удалять.
# - жилая площадь
# Основная часть квартир имеет жилую площадь до 75 кв. м. Судя по диаграмме размаха есть много выбросов и их не целесообразно удалять.
# - площадь кухни
# Основная часть площадей кухонь занимает до 20 кв. м. Судя по диаграмме размаха есть много выбросов и их не целесообразно удалять.
# - цена объекта
# Основная часть квартир стоит до 8.000.000 рублей, есть много выбросов, но удалить мы их не можем из-за большой потери данных.
# - количество комнат
# В основном все квартиры имеют до 6 комнат включительно, очень редко попадаются квартиты с большим количеством комнат.
# - высота потолков
# Высота потолков не может быть меньше 1.5 метров и выше 3 метров (для квартир), поэтому мы удаляем все выбросы.
# - общее количество этажей в доме
# Основная часть домов высотой до 30 этажей.
# Очень малое количество домов, которые выше 30 этажей, посчитаем их за выбросы и удалим.
# - расстояние до центра города в метрах
# Основная часть находится на расстоянии 6000 метров от центра города, но расстояния больше 3500 метров считаем выбросами.
# - расстояние до ближайшего парка
# Оснавная часть квартир находится далеко от парков, нормальным значение считаем расстояние до 750 метров.

# %% [markdown]
# <div class="alert alert-success">
# ✔️ Комментарий ревьюера ✔️
#
# Хороший результат. Хочу добавить, что обычно размеры двухкомнатных квартир составляют от 50 до 100 квадратных метров, что и соответствует проведенному анализу.
#
# Могу посоветовать на будущее хорошую статью по оформлению графиков:
#     https://devpractice.ru/matplotlib-lesson-3-3-text-elements/
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера ❌**
#
#    Также важно посмотреть, какая доля от изначального количества данных осталась после фильтрации. Для этого рекомендую зафиксировать начальное количество данных в переменную с помощью метода shape, а затем использовать ее в рассчетах. Прикрепляю полезную ссылку: https://tonais.ru/library/poluchenie-formy-razmera-dataframe Обращаю внимание, что мы можем провести актуальный анализ, если у нас есть не менее 90 % от изначального числа данных
#
# </div>

# %%
shape = data.shape
print('DataFrame Shape :', shape)
print('Number of rows :', shape[0])
print('Number of columns :', shape[1])
# Out:
# DataFrame Shape : (22026, 29)
# Number of rows : 22026
# Number of columns : 29

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Потеряли всего 1600 строк, меньше 10% процентов информации(почти 7%). Продолжаем анализ дальше.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2 ✔️**
#
#    👍
#
# </div>

# %%
data['days_exposition'].hist()
# Out:
# <AxesSubplot:>

# %%
data['days_exposition'].describe()
# Out:
# count    19204.000000
# mean       175.328369
# std        214.651902
# min          1.000000
# 25%         44.000000
# 50%         92.000000
# 75%        221.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# В среднем квартиры продавались за 152 дня, но медианное значение 72 дня, значит продажи квартиры за 2 с половиной месяца можно считать быстрыми, а продажи дольше 5 мясяцев -- долгими.

# %%
# Код ревьюера
data['days_exposition'].hist(bins=50, range=(0,100), figsize=(12, 7))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#
#
#
#
#
#    На гистограмме действительно заметны пики примерно через 45, 60 и 90 дней после начала продажи. Можно посмотреть на условия размещения объявлений в Яндекс.Недвижимости - https://yandex.ru/support/realty/owner/home/add-ads-housing.html С учетом того, что после формирования датасета правила размещения поменялись, эти пики являются следами автоматического снятия объявлений - поэтому оценивать скорость продажи можно также по диаграмме размаха
#
# </div>

# %%
data.corr()
# Out:
#                      total_images  last_price  total_area     rooms  \
# total_images             1.000000    0.091098    0.117216  0.105161
# last_price               0.091098    1.000000    0.622636  0.335232
# total_area               0.117216    0.622636    1.000000  0.749069
# rooms                    0.105161    0.335232    0.749069  1.000000
# ceiling_height           0.030398    0.176343    0.247985  0.078112
# floors_total             0.020456    0.038507   -0.023434 -0.203993
# living_area              0.105091    0.554301    0.935604  0.832239
# floor                    0.038408    0.055929    0.005644 -0.138718
# is_apartment             0.004422    0.021975    0.022353  0.004737
# studio                  -0.027675   -0.026255   -0.079737 -0.152182
# open_plan               -0.025132   -0.013529   -0.046876 -0.094289
# kitchen_area             0.094782    0.480193    0.646368  0.283548
# balcony                  0.047511    0.026768    0.036320  0.006107
# ...

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Для того, что бы понять есть ли взаимосвязь цены с какими-то признаками постоим тепловую карту корреляции и заметим:
# 1) Цена от общей площади имеет большую зависимость(коэффициент корреляции 0.62)
# 2) Цена от жилой площади имеет достаточно большую зависимость(коэффициент корреляции 0.5)
# 3) Цена от площади кухнии имеет достаточно большую зависимость(коэффициент корреляции 0.4)
# 4) Цена от этажа, на котором расположена квартира не имеет никакой зависимости(коэффициент корреляции 0.056)
# 5) Цена от даты размещения практически не имеет никакой зависимости(коэффициент корреляции 0.011,0.0073,-0.035)

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера ❌**
#
#    Здесь нас попросили построить именно графики, а не только матрицу корреляции
#
# </div>

# %%
pivot_table_area = data.pivot_table(index = 'total_area', values = 'last_price', aggfunc = 'mean')
pivot_table_area.plot()
# Out:
# <AxesSubplot:xlabel='total_area'>

# %% [markdown]
# На графике видна зависимость.

# %%
pivot_table_living_area = data.pivot_table(index = 'living_area', values = 'last_price', aggfunc = 'mean')
pivot_table_living_area.plot()
# Out:
# <AxesSubplot:xlabel='living_area'>

# %% [markdown]
# На графике видна зависимость.

# %%
pivot_table_kitchen_area = data.pivot_table(index = 'kitchen_area', values = 'last_price', aggfunc = 'mean')
pivot_table_kitchen_area.plot()
# Out:
# <AxesSubplot:xlabel='kitchen_area'>

# %% [markdown]
# На графике видна зависимость.

# %%
pivot_table_rooms = data.pivot_table(index = 'rooms', values = 'last_price', aggfunc = 'mean')
pivot_table_rooms.plot()
# Out:
# <AxesSubplot:xlabel='rooms'>

# %% [markdown]
# На графике видна зависимость, но есть и выбросы, может быть эти квартиры находятся в центре.

# %%
pivot_table_floor_type = data.pivot_table(index = 'floor_type', values = 'last_price', aggfunc = 'mean')
pivot_table_floor_type.plot()
# Out:
# <AxesSubplot:xlabel='floor_type'>

# %% [markdown]
# Можно заметить, цена квартир на первом этаже гораздо ниже относительно других этажей.

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v2✔️**
#
#    Хорошие результаты. Отмечу, что скорее всего, низкую цену на квартиры на первых этажах можно аргументировать плохими условиями - шум от улиц и охлаждаемость помещения зимой.
#
# </div>

# %%
pivot_table_time = data.pivot_table(index = 'year_count', values = 'last_price', aggfunc = 'mean')
pivot_table_time.plot(kind='bar', figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='year_count'>

# %% [markdown]
# В 2014 году квартиры были дороже, далее наблюдается плавный спад, а в 2019 небольшой поъем цен.

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌ Комментарий ревьюера v2❌**
#
#    А вот от года, месяца и дня недели нам больше подойдет график типа bar, так как зависимость стоимости от этих столбцов не линейна
#
# </div>

# %%
pivot_table_time1 = data.pivot_table(index = 'month_count', values = 'last_price', aggfunc = 'mean')
pivot_table_time1.plot(kind='bar', figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='month_count'>

# %% [markdown]
# Зависимости практически нет, но в сентябре квартиры чуть дороже.

# %%
pivot_table_time2 = data.pivot_table(index = 'weekday_day', values = 'last_price', aggfunc = 'mean')
pivot_table_time2.plot(kind='bar', figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='weekday_day'>

# %% [markdown]
# Разницы практически нет, но в субботу квартиры немного дороже.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Постарался исправиться, увидел свои ошибки!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Исправил графики, теперь наглядно видно в какой день, месяц и год цена выше!
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v3✔️**
#
#    Получилось отлично👍
#
# </div>

# %%
average_price = data.pivot_table(index='locality_name', values='price_square_meter', aggfunc=['mean', 'count'])
average_price.columns = ['mean', 'count']
average_price = average_price.sort_values('count', ascending = False).head(10)
average_price
# Out:
#                             mean  count
# locality_name
# Санкт-Петербург    112326.850341  14229
# поселок Мурино      86254.249348    552
# поселок Шушары      78921.770228    438
# Всеволожск          68929.887817    394
# Пушкин             102738.449345    351
# Колпино             75783.983780    328
# поселок Парголово   90675.627492    327
# Гатчина             68933.550993    302
# деревня Кудрово     93002.173411    299
# Выборг              57852.707366    224

# %% [markdown]
# По данной сводной таблице можно увидеть:
# Самая большая цена за квадратный метр в Санкт-Петербурге 112.333 и Пушкине 102.738, а меньше всего в Выборге -- 57.852 и Гатчине -- 68.945.

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#    Верно
#
# </div>

# %%
distance_to_center_piter = data.query('locality_name == "Санкт-Петербург"').pivot_table(index='distance_to_center', values='last_price', aggfunc='mean')
distance_to_center_piter
# Out:
#                       last_price
# distance_to_center
# 0.0                 4.758726e+07
# 1.0                 1.672763e+07
# 2.0                 1.580826e+07
# 3.0                 1.064470e+07
# 4.0                 1.284096e+07
# 5.0                 1.310248e+07
# 6.0                 1.250223e+07
# 7.0                 1.347645e+07
# 8.0                 9.330060e+06
# 9.0                 6.633419e+06
# 10.0                6.325002e+06
# 11.0                6.124944e+06
# 12.0                5.799775e+06
# 13.0                6.064030e+06
# 14.0                5.587329e+06
# 15.0                5.814832e+06
# 16.0                5.337894e+06
# 17.0                5.289829e+06
# 18.0                5.055743e+06
# 19.0                5.062709e+06
# 20.0                4.611579e+06
# 21.0                5.506572e+06
# 22.0                5.393633e+06
# 23.0                4.985376e+06
# 24.0                3.854430e+06
# 25.0                4.088954e+06
# ...

# %%
distance_to_center_piter.plot(grid=True)
# Out:
# <AxesSubplot:xlabel='distance_to_center'>

# %% [markdown]
# Можем заметить как с каждым километром от центра города цена падает, например, в самом центре квартира стоит 18млн., а в трех километрах от центра уже 10 млн.
# Самые дешевые квартиры в 27 км от центра и стоят в среднем 2.2млн. Дальше 9 км от центра, цены примерно одиннаковые(4-5млн). Резкий спад на каждом километре виден только до 9 км.
# По графику хорошо видна аномалия на третьем километре от центра, цены там состовляют 10млн. Можно объяснить это плохим районом или чем-то подобным.

# %% [markdown]
# <div class="alert alert-success">
# ✔️ Комментарий ревьюера ✔️
#
# Верно. На графике после 7 км заметно, что цена меняется. Это возможный центр города.
#
# Если интересно, то самый дорогой по стоимости жилья район в Санкт-Петербурге риелторы назвали "Золотой треугольник". Дома "Золотого треугольника" находятся в пределах Невского проспекта, набережной реки Фонтанки и Дворцовой набережной.
# Для географической справки: https://zen.yandex.ru/media/id/5cb4ebcc0a51a300b5b1f60d/zolotoi-treugolnik-sanktpeterburga-chto-eto-i-gde-nahoditsia-5edf942db1204610073e88b2
#
# </div>

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# Исследовав объявления о продаже квартир можно сделать вывод:
# 1) На цену квартиры больше влияет общая площадь (коэффициент корреляции 0.62)и ее местонахождение относительно центра города.
# 2) Прослеживаются и аномалии, например, как стоимость квартир на третьем и четвертом километре от центра гораздо ниже чем могла бы быть, связанно это, думаю с неблагополучным/шумным/грязным районом.
# 3) Средняя стоимость квадратного метра больше всего в Санкт-Петербурге -- 112.333 и Пушкине -- 102.738, а меньше всего в Выборге -- 57.852 и Гатчине -- 68.945.
# 4) Так же можно заметить средний срок продажи квартир:
# - быстрая продажа занимает до двух с половиной месяцев
# - нормальный срок около 152 дней
# - долгая продажа длится от 5 мясяцев

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера ✔️**
#
#    Александр, проведен основательный и подробный анализ. Все наглядно - графики и гистограммы подтверждают обоснованные выводы. Учти мои замечания. Возможно, придется немного подправить выводы. Жду твой проект на повторное ревью. Успехов!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Михаил, спасибо большое за проверку моей работы! Постарался учесть все твои замечания и проработать их!
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# **✔️ Комментарий ревьюера v3✔️**
#
#    Александр, замечания устранены 👍. Уверен, мои советы пригодятся тебе в новых проектах. Успехов в обучении! 😉
#
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
